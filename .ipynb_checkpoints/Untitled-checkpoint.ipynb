# %%
import vk
import pandas as pd
import numpy as np

# %%
session = vk.Session(
        access_token="1196d2715eca22172df04c79f1a3d6903bd2c2596afa0636a40068e957f445a9e68708baab033b33d064d")
vk_api = vk.API(session)
vids = vk_api.friends.get(owner_id=287475349,fields='city,domain')

# %%
fr_df=pd.DataFrame(vids)

# %%
fr_df
# Out:
#        city deactivated                  domain  first_name         last_name  \
# 0       1.0         NaN                  starry        Олег          Медведев
# 1       1.0         NaN                id409037       Ольга        Подольская
# 2       1.0         NaN          vasiliivolchok     Василий  Волчок-Русакович
# 3       1.0         NaN               id1665081   Маргарита          Андреева
# 4       1.0         NaN               id2199366        Даша          Сахарова
# 5     140.0         NaN                lubichgr    Геннадий             Любич
# 6       0.0         NaN               id4447674     Natasha              Jess
# 7       1.0         NaN                 sindbag    Анатолий          Бардуков
# 8       1.0         NaN          michal_hal_hal      Михаль        Розенвальд
# 9       1.0         NaN               id6486564      Никита             Левин
# 10      1.0         NaN            nikolaeva_ka   Екатерина         Николаева
# ...
