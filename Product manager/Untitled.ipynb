# %%
import vk
import pandas as pd
import numpy as np

# %%
fr_df=pd.read_csv("./990.csv")

# %%
count=0
for row in range(len(fr_df)):
    for i in range(1, 31):
        if fr_df.iloc[row, i]==-1:
            count+=1
            break
print(count)
# Out:
# 990

# %%
fr_df
# Out:
#      Unnamed: 0  albums  alcohol  audios       bdate       city  country  \
# 0             0     NaN      NaN     NaN         NaN        NaN      NaN
# 1             1     2.0     -1.0   254.0        23.8      183.0      4.0
# 2             2     1.0     -1.0     0.0       17.12        2.0      1.0
# 3             3    14.0     -1.0   671.0   27.6.1988        2.0      1.0
# 4             4     4.0     -1.0   873.0    6.1.1988      699.0     19.0
# 5             5     0.0     -1.0     0.0         7.9      314.0      2.0
# 6             6     0.0     -1.0   674.0        22.3       71.0      1.0
# 7             7     5.0      2.0    22.0        21.1      169.0      1.0
# 8             8     5.0      3.0   270.0   16.4.1990        2.0      1.0
# 9             9     1.0     -1.0     0.0        21.8        1.0      1.0
# 10           10     8.0      3.0   361.0         8.5        2.0      1.0
# 11           11     0.0     -1.0     0.0         4.2      169.0      1.0
# ...
